# %%
# Unir todos los DataFrames en uno solo
df_total = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8], ignore_index=True)

# Mostrar las primeras filas del DataFrame combinado
df_total.head()
# Out:
#     Fecha  Medio   Posición           Artista             Canción  \
# 0  ene-21  Radio  #¿NOMBRE?  Sebastián Yatra        Chica Ideal
# 1  ene-21  Radio  #¿NOMBRE?          Camilo        Vida De Rico
# 2  ene-21  Radio  #¿NOMBRE?          Maluma               Hawai
# 3  ene-21  Radio  #¿NOMBRE?    Harry Styles    Watermelon Sugar
# 4  ene-21  Radio  #¿NOMBRE?          Donald      Verano Naranja
#
#         Género Nacionalidad Artista + Canción
# 0     Colombia   Pop Latino               NaN
# 1     Colombia   Pop Latino               NaN
# 2     Colombia     Reguetón               NaN
# 3  Reino Unido          Pop               NaN
# 4        Chile          Pop               NaN

# %%
import pandas as pd

# Try different delimiters and error handling
df1 = pd.read_csv('Base_Musical_Hoja1.csv', sep=';', on_bad_lines='skip')  # Try semicolon as delimiter and skip bad lines
# df1 = pd.read_csv('Base_Musical_Hoja1.csv', sep='\t', on_bad_lines='skip')  # Try tab as delimiter and skip bad lines
# df1 = pd.read_csv('Base_Musical_Hoja1.csv', error_bad_lines=False)  # Skip bad lines without raising an error

df2 = pd.read_csv('Base_Musical_Hoja2.csv', sep=';', on_bad_lines='skip')
df3 = pd.read_csv('Base_Musical_Hoja3.csv', sep=';', on_bad_lines='skip')
df4 = pd.read_csv('Base_Musical_Hoja4.csv', sep=';', on_bad_lines='skip')
df5 = pd.read_csv('Base_Musical_Hoja5.csv', sep=';', on_bad_lines='skip')
df6 = pd.read_csv('Base_Musical_Hoja6.csv', sep=';', on_bad_lines='skip')
df7 = pd.read_csv('Base_Musical_Hoja7.csv', sep=';', on_bad_lines='skip')
df8 = pd.read_csv('Base_Musical_Hoja8.csv', sep=';', on_bad_lines='skip')

# Mostrar las primeras filas de cada uno (puedes elegir cuál mostrar)
df1.head()
# Out:
#     Fecha  Medio   Posición           Artista             Canción  \
# 0  ene-21  Radio  #¿NOMBRE?  Sebastián Yatra        Chica Ideal
# 1  ene-21  Radio  #¿NOMBRE?          Camilo        Vida De Rico
# 2  ene-21  Radio  #¿NOMBRE?          Maluma               Hawai
# 3  ene-21  Radio  #¿NOMBRE?    Harry Styles    Watermelon Sugar
# 4  ene-21  Radio  #¿NOMBRE?          Donald      Verano Naranja
#
#         Género Nacionalidad
# 0     Colombia   Pop Latino
# 1     Colombia   Pop Latino
# 2     Colombia     Reguetón
# 3  Reino Unido          Pop
# 4        Chile          Pop

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-50ae6a62-f0ec-4359-b234-65ec29361e19" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-50ae6a62-f0ec-4359-b234-65ec29361e19">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
